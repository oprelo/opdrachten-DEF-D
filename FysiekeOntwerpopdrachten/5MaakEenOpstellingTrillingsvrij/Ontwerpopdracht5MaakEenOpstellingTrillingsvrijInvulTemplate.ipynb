# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 55     |  |
# | :-------------|:-------------|
# | Moene van der Wiel| 6583733 |
# | Eline Deiters| 6283136 |
# | Zenn Idu| 6225497 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 55     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 12:00 | Eline |
# | ontwerp-eis berekenen| 12:00 | Moene en Zenn|
# | groepsoverleg | 12:15 | hele groep |
# | synthese | 13:45 | hele groep |
# | simulatie | 14:00 | hele groep |
# | fabricage | 15:00 | hele groep |
# | meetingen | 16:00 | hele groep |
# | opruimen en documentatie | 17:00 | hele groep |
# | Pauze 1| 10:20-10:40 | hele groep |
# | Pauze 2| 12:30-13:30 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 3 |
# | hoe lang voor één meting | 3 min |
# | verwacht nauwkeurigheid meting | 0.2 m |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
f = 5 #hz
f_0 = f/2
w_0 = 2*np.pi*f_0
print(f'f_0 = {f_0:.2f} Hz, w_0 = {w_0:.1f} rad/s')
# Out:
# f_0 = 2.50 Hz, w_0 = 15.7 rad/s

# %%
# Voeg hier je plot in.
f_v = np.linspace(0,20,1000)
A_A = abs(1/(1-((2*np.pi*f_v)**2)/(w_0**2)))

plt.figure(figsize=(9,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(f_v,A_A)
plt.xlabel('f_v (Hz)')
plt.ylabel('A_m/A_v (-)')
plt.show()

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g = 9.81
dx_min = g/(w_0**2)
print(f'dx_min = {dx_min:.4f} m')
# Out:
# dx_min = 0.0398 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().
m = np.linspace(0,1,100)

dx_mid = 2*dx_min
dx_max = 5*dx_min

c_min = g*m/dx_min
c_mid = g*m/dx_mid
c_max = g*m/dx_max

plt.figure(figsize=(9,5))
plt.plot(m,c_min,'g',label='dx_min')
plt.plot(m,c_mid,'b',label='dx_mid')
plt.plot(m,c_max,'r',label='dx_max')
plt.xlabel('m (kg)')
plt.ylabel('c (N/m)')
plt.legend()
plt.savefig('dx_plot.png',dpi=400)
plt.show()

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - c verlagen door een zwakkere veer te nemen
# - m verhogen door een grotere massa te gebruiken
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 0.07m

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="foto_schets.jpg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# $\Delta x = 0.85$ m
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Nee, we hadden een kleinere veer nodig met een lagere veerconstante.
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# Als het systeem op 1.5 Hz beweegt vind er resonatie plaats. De uitwijking van de veer wordt dan zodanig groot dat er platsiche deformatie optreed waardoor de veer nier meer linear reageert volgens de we van Hooke.
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Ja, zolang we niet met een al te grote aplitude meten op de eigenfrequentie.
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Volgens de berekeningen en testen wel.
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.

W_0_systeem = np.sqrt(g/0.085)

A_A_systeem = abs(1/(1-((2*np.pi*f_v)**2)/(W_0_systeem**2)))

plt.figure(figsize=(9,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(f_v,A_A,'r', label='min eigenfrequentie')
plt.plot(f_v,A_A_systeem,'g', label='eigenfrequentie systeem')
plt.xlabel('f_v (Hz)')
plt.ylabel('A_m/A_v (-)')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.
f_meeting = np.array([9.0,6.2,5.5,3.5,1.4,1.6])
A_v = np.array([4.82,4.69,4.60,1.52,0.26,0.19])
A_m = np.array([0.43,0.60,1.31,0.90,0.72,1.30])

u_f = 0.1 #Hz
u_A = 0.2 #m

A_A_meeting = A_m/A_v

u_A_A = A_A_meeting*np.sqrt((u_A/A_v)**2 + (u_A/A_m)**2)

plt.figure(figsize=(9,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(f_v,A_A,'r--', label='min eigenfrequentie')
plt.plot(f_v,A_A_systeem,'g--', label='eigenfrequentie systeem')
plt.errorbar(f_meeting,A_A_meeting,u_A_A,u_f,'b.', label='meeringen')
plt.xlabel('f_v (Hz)')
plt.ylabel('A_m/A_v (-)')
plt.legend()
plt.savefig('A_f_plot.png',dpi=400)
plt.show()

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# # leerdoel: parameters #

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
f = 5 #hz
f_0 = f/2
w_0 = 2*np.pi*f_0
print(f'f_0 = {f_0:.2f} Hz, w_0 = {w_0:.1f} rad/s')
# Out:
# f_0 = 2.50 Hz, w_0 = 15.7 rad/s

# %%
# Voeg hier je plot in.
f_v = np.linspace(0,20,1000)
A_A = abs(1/(1-((2*np.pi*f_v)**2)/(w_0**2)))

plt.figure(figsize=(9,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(f_v,A_A)
plt.xlabel('f_v (Hz)')
plt.ylabel('A_m/A_v (-)')
plt.show()

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g = 9.81
dx_min = g/(w_0**2)
print(f'dx_min = {dx_min:.4f} m')
# Out:
# dx_min = 0.0398 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().
m = np.linspace(0,1,100)

dx_mid = 2*dx_min
dx_max = 5*dx_min

c_min = g*m/dx_min
c_mid = g*m/dx_mid
c_max = g*m/dx_max

plt.figure(figsize=(9,5))
plt.plot(m,c_min,'g',label='dx_min')
plt.plot(m,c_mid,'b',label='dx_mid')
plt.plot(m,c_max,'r',label='dx_max')
plt.xlabel('m (kg)')
plt.ylabel('c (N/m)')
plt.legend()
plt.savefig('dx_plot.png',dpi=400)
plt.show()

# %% [markdown]
# # leerdoel: ontwerp #

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - c verlagen door een zwakkere veer te nemen
# - m verhogen door een grotere massa te gebruiken
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 0.07m

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="foto_schets.jpg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# $\Delta x = 0.85$ m
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Nee, we hadden een kleinere veer nodig met een lagere veerconstante.
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# Als het systeem op 1.5 Hz beweegt vind er resonatie plaats. De uitwijking van de veer wordt dan zodanig groot dat er platsiche deformatie optreed waardoor de veer nier meer linear reageert volgens de we van Hooke.
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Ja, zolang we niet met een al te grote aplitude meten op de eigenfrequentie.
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Volgens de berekeningen en testen wel.
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.

W_0_systeem = np.sqrt(g/0.085)

A_A_systeem = abs(1/(1-((2*np.pi*f_v)**2)/(W_0_systeem**2)))

plt.figure(figsize=(9,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(f_v,A_A,'r', label='min eigenfrequentie')
plt.plot(f_v,A_A_systeem,'g', label='eigenfrequentie systeem')
plt.xlabel('f_v (Hz)')
plt.ylabel('A_m/A_v (-)')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.
f_meeting = np.array([9.0,6.2,5.5,3.5,1.4,1.6])
A_v = np.array([4.82,4.69,4.60,1.52,0.26,0.19])
A_m = np.array([0.43,0.60,1.31,0.90,0.72,1.30])

u_f = 0.1 #Hz
u_A = 0.2 #m

A_A_meeting = A_m/A_v

u_A_A = A_A_meeting*np.sqrt((u_A/A_v)**2 + (u_A/A_m)**2)

plt.figure(figsize=(9,5))
plt.xscale('log')
plt.yscale('log')
plt.plot(f_v,A_A,'r--', label='min eigenfrequentie')
plt.plot(f_v,A_A_systeem,'g--', label='eigenfrequentie systeem')
plt.errorbar(f_meeting,A_A_meeting,u_A_A,u_f,'b.', label='meeringen')
plt.xlabel('f_v (Hz)')
plt.ylabel('A_m/A_v (-)')
plt.legend()
plt.savefig('A_f_plot.png',dpi=400)
plt.show()
